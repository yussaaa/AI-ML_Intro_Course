# %%
import numpy as np

# %%
random_numbers = np.random.rand(100)
print(len(random_numbers))
# Out:
# 100

# %%
tt = random_numbers.tolist()

# %%
tt
# Out:
# [0.42874029085121534,
#  0.7355941051977292,
#  0.6949924064406205,
#  0.9279610867104591,
#  0.13920015893757431,
#  0.5801978526626376,
#  0.9255221181304346,
#  0.5422117539951465,
#  0.29718406959621024,
#  0.7770593093880471,
#  0.46866205030649954,
#  0.016719386385047108,
#  0.23706973910219065,
#  0.3471376001077078,
#  0.4787915767478933,
#  0.41533427981036475,
#  0.05914896793406477,
#  0.6380763639353949,
#  0.7782902979897931,
#  0.3011463400722284,
#  0.6329384582915721,
#  0.2549636400612505,
#  0.38902957090688794,
#  0.6054230479518324,
#  0.3970474646003509,
#  0.0064124372109931604,
#  0.6479839190801122,
#  0.3591065112678029,
#  0.32457574944977574,
#  0.5303722524916687,
#  0.5793949455550761,
#  0.3527122789841578,
#  0.48918560548683576,
#  0.613333111609253,
#  0.14902424350675525,
#  0.7927056529224646,
#  0.3763237894438315,
#  0.5993883790952489,
#  0.9912785477940674,
#  0.15512619479570466,
#  0.837007387973724,
#  0.7642850356775921,
# ...

# %%
ttt = tt * 2

# %%
len(ttt)
# Out:
# 200
